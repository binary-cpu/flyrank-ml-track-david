# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane is "Prioritizing High-Value Content for Refresh based on Decline and Potential Impact."
#
# This lane is important since the data we have shows clear indicators of content performance (e.g. `impressions_90d`, `trend_direction`) and decay factors (`days_since_last_update`). By focusing on content that’s declining, but still has a significant volume of impressions, one can strategically focus refresh efforts. This guarantees that resources are allocated to the areas that will best bring back lost visibility and traffic, not content that’s already stable or has little performance.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My work is focused on improving the decision-making process of  which content pieces to prioritize for a refresh. This will be especially useful for content strategists, editors, and SEO teams. The cost of a suboptimal recommendation is high: wasting resources on content that doesn’t need a refresh or refreshing content that doesn’t show any measurable improvement means wasted time, effort, and budget. Not refreshing high-value content that is actually declining, in contrast, can lead to a long-term decrease in organic traffic, conversions, and overall brand authority.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-track-david-main/flyrank-ml-track-david-main/data/raw/content_refresh_anonymized.csv")

df["is_declining_label"] = (
    df["trend_direction"].str.lower() == "down"
).astype(int)

print("Total Pages:", len(df))
print("Declining Rate:", round(df["is_declining_label"].mean(), 3))

df[["impressions_90d", "days_since_last_update"]].describe()
# Out:
# Total Pages: 30000
# Declining Rate: 0.542
#        impressions_90d  days_since_last_update
# count     30000.000000            30000.000000
# mean       5200.366300               46.098300
# std       16838.019547               42.078709
# min           1.000000                1.000000
# 25%          81.000000               20.000000
# 50%         731.000000               20.000000
# 75%        3615.250000              104.000000
# max      517715.000000              373.000000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work will give observed, descriptive insights into content performance trends and identifying declining pages. The insights will be directional and decision-supportive, helping content teams prioritize refresh efforts based on quantifiable metrics like volume of impressions and decline rates.
#
# However, this analysis cannot provide causal proof as to why content is declining, nor can it guarantee the success of a refresh strategy. It can’t “anticipate Google’s algorithm” or other external market changes. The recommendations will be based on past data patterns and should be utilized as strategic input and not as a definitive prediction of future outcomes or direct causal links.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
